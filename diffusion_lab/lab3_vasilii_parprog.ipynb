# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.optimize
import seaborn as sns

# %% [markdown]
# ## From C file:

# %%
answer_cross = np.zeros((100, 100))

i = 0
with open("output_file.txt") as f:
    for line in f:
        data = [float(x) for x in line.split()]
        for j in range(100):
          answer_cross[i][j] = data[j]
        i += 1
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-78-ad3632d5619e> in <module>
#       2
#       3 i = 0
# ----> 4 with open("output_file.txt") as f:
#       5     for line in f:
#       6         data = [float(x) for x in line.split()]
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output_file.txt'

# %%
import seaborn as sns
sns.heatmap(answer_cross)
# Out:
# <AxesSubplot:>
